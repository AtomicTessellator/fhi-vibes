# %%
import json
import yaml
import pickle
from pprint import pprint

# %%
with open('band.yaml') as f:
    bands = yaml.load(f, Loader=yaml.Loader)

# %%
pprint(bands)
# Out:
# {'lattice': [[-0.0, 2.71303376291, 2.71303376291],
#              [2.71303376291, -0.0, 2.71303376291],
#              [2.71303376291, 2.71303376291, 0.0]],
#  'natom': 2,
#  'npath': 7,
#  'nqpoint': 357,
#  'phonon': [{'band': [{'frequency': -9.8e-08},
#                       {'frequency': 1.75e-07},
#                       {'frequency': 3.516e-07},
#                       {'frequency': 15.4188566727},
#                       {'frequency': 15.4188566727},
#                       {'frequency': 15.4188566727}],
#              'distance': 0.0,
#              'label': '$\\mathrm{\\mathsf{\\Gamma}}$',
#              'q-position': [0.0, 0.0, 0.0]},
#             {'band': [{'frequency': 0.099536883},
#                       {'frequency': 0.099536883},
#                       {'frequency': 0.1515133099},
#                       {'frequency': 15.417969447},
#                       {'frequency': 15.417969447},
#                       {'frequency': 15.4186037814}],
# ...

# %%
with open('band.json', 'w') as f:
    json.dump(bands, f)

# %%
with open('band.json') as f:
    bands2 = json.load(f)

# %%
bands == bands2
# Out:
# True
